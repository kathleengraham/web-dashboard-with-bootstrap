# %% [markdown]
# # Converting CSV File to pandas DataFrame to HTML Table

# %%
import pandas as pd

# %%
cities_df = pd.read_csv('cities.csv', encoding="utf-8")
cities_df
# Out:
#                City  Cloudiness Country        Date  Humidity  Latitude  \
# 0         Cape Town           0      ZA  1561489203        71    -33.93
# 1           Yarensk           3      RU  1561489809        69     62.17
# 2           Rikitea          20      PF  1561489499        83    -23.12
# 3           Rikitea          20      PF  1561489499        83    -23.12
# 4            Bereda           0      ES  1561489813        64     43.27
# 5             Vaini          46      IN  1561489546        89     15.34
# 6              Hilo           1      US  1561489561        61     19.71
# 7            Leeton           0      AU  1561489817       100    -34.55
# 8               Gao          22      ML  1561489818        11     16.28
# 9          Maragogi          90      BR  1561489819        74     -9.01
# 10           Albany          75      US  1561489244        61     42.65
# 11    Pacific Grove           1      US  1561489821        63     36.62
# ...

# %%
cities_df.to_html('cities-table.html')
